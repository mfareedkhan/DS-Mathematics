# %% [markdown]
# # **Linear Algebra in Python:**

# %%
import numpy as np

# %% [markdown]
# ### **Solving System of `Simple` Linear Equations:**
# 2x+3y = 8
#
# 5x+4y = 20
#
# AX = B
# - `A` is a coefficient matrix
# - `X` is a variable matrix
# - `B` is a constant matrix

# %%
# coefficient matrix A
A = np.array([[2, 3], [5, 4]]) # 2x2 matrix 
A
# Out:
# array([[2, 3],
#        [5, 4]])

# %%
# constant matrxi B
B = np.array([8,20]) # 1x2 matrix
B
# Out:
# array([ 8, 20])

# %%
# solve for x
X = np.linalg.solve(A, B)   # linalg = linear algebra module in numpy 
# linalg.solve() = function to solve linear equations
# A = coefficient matrix
# B = constant matrix 
# X = solution matrix
X
# Out:
# array([4., 0.])

# %% [markdown]
# ---

# %% [markdown]
# ### **Solving System of `Complex` Linear Equations:**
# - LaTeX is a programming environment for producing scientific documents.

# %% [markdown]
# \[
# \begin{align*}
# (1 + 2i)x + (2 - i)y &= 4 + i \\
# (3 - i)x + 4y &= 3 + 4i
# \end{align*}
# \]

# %%
#1 Coefficients Matrix A with complex numbers:
A_complex = np.array([[1+2j, 2-1j], [3-1j, 4]])
print(A_complex)
print('------------------------')

#2 Constants Matrix B with complex numbers:
B_complex = np.array([4+1j, 3+4j])
print(B_complex)
print('------------------------')

#3 Solving for X in the complex case:
X_complex = np.linalg.solve(A_complex, B_complex)
print(X_complex)
# Out:
# [[1.+2.j 2.-1.j]
#  [3.-1.j 4.+0.j]]
# ------------------------
# [4.+1.j 3.+4.j]
# ------------------------
# [-0.11176471-0.45294118j  0.94705882+1.31176471j]

# %% [markdown]
# ---
# ### **SVD in Python:**
# AX = B
# - `A` is a coefficient matrix
# - `X` is a variable matrix
# - `B` is a constant matrix
#
# `A = UΣV^T`
# - `U` is an m × m orthogonal matrix.
# - `V` is an n × n orthogonal matrix.
# - `Σ` is an m × n matrix whose ith diagonal entry equals the ith singular value σi for i = 1,...,r. All other entries of Σ are zero.
#
# AX = B ==> `(UΣV^T)X = B`

# %%
#1 Generate a Matrix  of 4x3 Dataset:
A = np.random.rand(4,3) # 4x3 matrix
A
# Out:
# array([[0.50040555, 0.74248702, 0.98310949],
#        [0.94923697, 0.58396436, 0.6293259 ],
#        [0.08601606, 0.37814581, 0.503946  ],
#        [0.39651455, 0.77136105, 0.04392819]])

# %%
#2 Lets apply SVD here:
U, Σ, VT = np.linalg.svd(A)
#> U = left singular vectors
#> Sigma = singular values
#> VT = right singular vectors

#3 Print each Matrix separately:
print(U.shape)
print("U Matrix=", U)
#> involves eigenvalues and eigenvectors of AAT (A transpose)
print("--------------------------------")
print(Σ.shape)
print("Σ Matrix=",Σ)
#> Σ gives diagonal values only (total diagonalvalues = total columns in A)
print("--------------------------------")
print(VT.shape)
print("VT Matrix=",VT)
#> involves eigenvalues and eigenvectors of AAT (A transpose)
# Out:
# (4, 4)
# U Matrix= [[-0.64642151 -0.47753735  0.2095914  -0.55692797]
#  [-0.61398747  0.24443647 -0.71284178  0.23479097]
#  [-0.28526113 -0.3758969   0.37900102  0.79604387]
#  [-0.35183051  0.75558614  0.55162149 -0.03191557]]
# --------------------------------
# (3,)
# Σ Matrix= [2.00589062 0.58551163 0.44541904]
# --------------------------------
# (3, 3)
# VT Matrix= [[-0.53359613 -0.60709444 -0.58882214]
#  [ 0.4446257   0.39087658 -0.8059302 ]
#  [-0.71943252  0.69184669 -0.06135956]]

# %%
U.shape
# Out:
# (4, 4)

# %%
Sigma.shape
# Out:
# (3,)

# %%
VT.shape
# Out:
# (3, 3)

# %% [markdown]
# ---
# ### **Vectors in Pyton:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a Vector in 2D space:
v = np.array([3,4])
print(v)
print(v.shape)
print(v.ndim)
# Out:
# [3 4]
# (2,)
# 1

# %% [markdown]
# Sure, here's a breakdown of the code:
#
# 1. `theta = np.radians(45)`: This line converts 45 degrees into radians. The `np.radians` function is used because the trigonometric functions in NumPy (`np.sin` and `np.cos`) expect their input in radians, not degrees.
#
# 2. `rotation_matrix = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]])`: This line defines the rotation matrix for a 45 degree rotation. In 2D space, a rotation matrix that rotates points counterclockwise by an angle of θ is given by this array. The `np.cos(theta)` and `np.sin(theta)` functions calculate the cosine and sine of `theta`, respectively.
#
# 3. `print(rotation_matrix)`: This line prints the rotation matrix.
#
# 4. `print("------------------------")`: This line prints a separator line for clarity in the output.
#
# 5. `print(v)`: This line prints the original vector `v` that is going to be transformed.
#
# 6. `v_transformed = np.dot(rotation_matrix, v)`: This line applies the rotation transformation to the vector `v`. The `np.dot` function performs the dot product of the rotation matrix and `v`, which effectively rotates `v` by 45 degrees counterclockwise.
#
# 7. `v_transformed`: This line outputs the transformed vector.
#
# If you want to rotate the vector to -45 degrees (or 45 degrees clockwise), you can simply change the sign of the angle when you define `theta`:
#
# ```python
# theta = np.radians(-45)  # Converting -45 degrees to radians
# ```
#
# The rest of the code remains the same.

# %%
# Plot the Vector 'v' using matplotlib::
plt.figure()  # create a new figure
plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r') # plot the vector
#> quiver = function to plot vectors in matplotlib 
#> 0,0 = x & y coordinates of the starting point (0,0) of vector
#> v[0], v[1] = x and y coordinates of vector (3,4)
#> angles = 'xy' means the arrow is defined by endpoints (x,y) and (x+u, y+v)
#> scale_units = 'xy' means x and y units are same
#> scale=1 means the scaling factor for the size of vectors & 1 means actual size
#> color = 'r' means color of vector is red

plt.xlim(0, 5) # set x-axis limits 
plt.ylim(0, 5) # set y-axis limits
plt.grid()     # add a grid
plt.title('2D Vector') # add a title
plt.xlabel('X axis')   # add x-axis label
plt.ylabel('Y axis')   # add y-axis label
plt.gca().set_aspect('equal', adjustable='box')   # set x and y axes scale to same scale
#> gca = get current axes & used to set the aspect ratio of the plot
plt.show()

# %% [markdown]
# ---
# ### **Linear Transformation:**
# > A linear transformation is a `function` that maps vectors from one vector space to another, preserving the operations of vector addition and scalar multiplication.
# - This means that the transformation of a vector sum or a scalar multiple of a vector can be consistently understood in terms of the transformation of individual vectors.
# - When axis (x,y,z) of cartesian coordinate system rotate at any angle
# - Change (rotation/skewness) in space is called linear transformation
#
# #### **Transformation is Linear Transformation when:**
# - All lines remain lines
# - There should not be any curve
# - Lines should always be evenly spaced
# - Origin should not move
# - Grid lines must be parallel
#
# **Examlpe: Rotation of the above vector to `-45-degree`**

# %% [markdown]
# \[
# \begin{bmatrix}
# \cos(45^\circ) & -\sin(45^\circ) \\
# \sin(45^\circ) & \cos(45^\circ)
# \end{bmatrix}
# \]

# %% [markdown]
# This is the basic rule for defining a rotation matrix in 2D space:
#
# `rotation_matrix = np.array([[np.cos(theta), -np.sin(theta)],
#                             [np.sin(theta), np.cos(theta)]])`
# - `theta` is the angle of rotation in radians (counterclockwise)
# - if you want to rotate by a different angle, simply change `theta` to desired angle (radians).

# %%
#1 Define the 'Rotation Matrix' for 45 degree rotation:
theta = np.radians(45)  # Converting 45 degrees to radians
#> Because(`np.sin` and `np.cos`) expect their input in radians, not degrees.

#2 Define the 'Rotation Matrix' for 45 degree rotation:
rotation_matrix = np.array([[np.cos(theta), -np.sin(theta)], 
                            [np.sin(theta), np.cos(theta)]])
#> rotation_matrix defines the rotation of 45 degrees in 2D space
print(rotation_matrix)
print("------------------------")
print(v)

#3 Applying the transformation to vector 'v':
v_transformed = np.dot(rotation_matrix, v) # np.dot = function to perform dot product of two matrices
v_transformed
# Out:
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
# ------------------------
# [3 4]
# array([-0.70710678,  4.94974747])

# %%
# Plotting the original and transformed vectors
plt.figure()
plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r', label='Original Vector')
plt.quiver(0, 0, v_transformed[0], v_transformed[1], angles='xy', scale_units='xy', scale=1, color='b', label='Transformed Vector')

plt.xlim(-1, 5)
plt.ylim(-1, 5)

plt.grid()

plt.title('2D Vector Transformation')

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
# Adjusting the plot to show the grid lines behind the vectors
plt.figure()
plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r', label='Original Vector')
plt.quiver(0, 0, v_transformed[0], v_transformed[1], angles='xy', scale_units='xy', scale=1, color='b', label='Transformed Vector')
plt.xlim(-5, 5)  # (-5,5) means x-axis limits are -5 to 5
plt.ylim(-5, 5)  # (-5,5) means y-axis limits are -5 to 5
plt.grid(True, which='both', linestyle='--', linewidth=0.5) 
#> which = 'both' means show grid lines on both x and y axes
#> linestyle = '--' means dashed line
#> linewidth = 0.5 means line width is 0.5

plt.axhline(y=0, color='k',linewidth=0.5) # axhline = function to plot horizontal line
plt.axvline(x=0, color='k',linewidth=0.5) # axvline = function to plot vertical line

plt.title('2D Vector Transformation')

plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.legend() # legend = function to show legend & legend means label 
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %% [markdown]
# ---
# ### **Shear Transformation:**
# > Shear transformation is a type of linear transformation that displaces each point in a fixed direction, by an amount proportional to its perpendicular distance from a line that is parallel to that direction. This transformation can be visualized as a "sliding" effect.
#
# In 2D space, a shear transformation can be along the x-axis or y-axis:
#
# - A shear `along the x-axis` changes the x-coordinate of a point while leaving the `y-coordinate unchanged`.
# - A shear `along the y-axis` changes the y-coordinate of a point while leaving the `x-coordinate unchanged`.
#
# - The `amount of shearing` is usually specified as a `factor` that multiplies the perpendicular distance from the line of reflection.
# - If this factor is `positive`, the direction of shearing is to the `right` for `x`-shearing or `upwards` for `y`-shearing.
# - If it's `negative`, the direction is to the `left` or `downwards`.

# %%
#1 Define the Shear Matrix for shearing along the x-axis with k = 2.5:
shear_factor = 2.5 
#> k=2.5 is the amount by which the x-coordinate of each point will be changed
shear_matrix = np.array([[1, shear_factor], [0, 1]])
#> 1 = no change in y-coordinate
#> [0,1] = no change in y-coordinate
print(shear_matrix)
# Out:
# [[1.  2.5]
#  [0.  1. ]]

# %% [markdown]
# - This is a 2x2 matrix that, when multiplied with a vector, applies the shear transformation to that vector.
# - The value of `shear_factor` is in the top right position of the matrix, which means that the shear is along the `x-axis`.
# - `First row` of the matrix specifies how the x-coordinate of a point will change.
# - `Second row` specifies how the y-coordinate of a point will change.

# %%
#2 Applying the Shear Transformation:
v = np.array([3,4])
v_sheared = np.dot(shear_matrix, v)
#> np.dot(shear_matrix, v) = performs the dot product of 'shear_matrix' and 'v'
print(v_sheared)
# Out:
# [13.  4.]

# %%
#3 Plotting the original, rotated, and sheared vectors:
plt.figure()
plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r', label='Original Vector')
plt.quiver(0, 0, v_transformed[0], v_transformed[1], angles='xy', scale_units='xy', scale=1, color='b', label='Rotated Vector')
plt.quiver(0, 0, v_sheared[0], v_sheared[1], angles='xy', scale_units='xy', scale=1, color='g', label='Sheared Vector')
plt.xlim(-5, 20)
plt.ylim(-5, 20)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.axhline(y=0, color='k',linewidth=0.5)
plt.axvline(x=0, color='k',linewidth=0.5)
plt.title('2D Vector Transformations')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %% [markdown]
# - `y = np.linspace(-5, 10, 10)`: Similarly, this line generates an array of 10 evenly spaced numbers between -5 and 10 and assigns it to the variable `y`.
#
# - `X, Y = np.meshgrid(x, y)`: This line uses the `np.meshgrid` function to generate a two-dimensional grid of coordinates. The `np.meshgrid` function takes two 1D arrays representing the Cartesian coordinates in the x-axis and y-axis, respectively. It returns two 2D arrays, which can be thought of as matrices. The first matrix `X` contains the x-coordinates for each point on the grid, and the second matrix `Y` contains the y-coordinates for each point on the grid.
#
# In simple terms, these lines of code are setting up a grid of points in 2D space, where the x-coordinates of the points are stored in `X` and the y-coordinates of the points are stored in `Y`. This is often used as a first step in generating a plot of a function over a 2D domain.

# %%
#4 Adjusting the plot to include the effect of shearing on the grid lines
# Creating a grid of points
x = np.linspace(-5, 10, 10)
#> Creates a 1D array of evenly spaced 10 points between -5 and 10 (along x-axis)
y = np.linspace(-5, 10, 10)
#> Creates a 1D array of evenly spaced 10 points between -5 and 10 (along y-axis)
X, Y = np.meshgrid(x, y)
#> Creates a 2D grid of points by combining x and y arrays

#5 Applying shear transformation to the grid points
X_sheared, Y_sheared = np.dot(shear_matrix, [X.ravel(), Y.ravel()])
X_sheared = X_sheared.reshape(X.shape)
Y_sheared = Y_sheared.reshape(Y.shape)

#6 Plotting the sheared grid lines
plt.figure()
plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r', label='Original Vector')
plt.quiver(0, 0, v_transformed[0], v_transformed[1], angles='xy', scale_units='xy', scale=1, color='b', label='Rotated Vector')
plt.quiver(0, 0, v_sheared[0], v_sheared[1], angles='xy', scale_units='xy', scale=1, color='g', label='Sheared Vector')

for i in range(len(x)):
    plt.plot(X_sheared[i, :], Y_sheared[i, :], 'k--', linewidth=0.5)
    plt.plot(X_sheared[:, i], Y_sheared[:, i], 'k--', linewidth=0.5)

plt.xlim(-5, 20)
plt.ylim(-5, 20)
plt.title('2D Vector Transformations with Sheared Grid')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
def gaussian_elimination(A, b):
    """
    Perform Gaussian elimination on system Ax = b.

    Args:
    A (numpy.ndarray): Coefficient matrix.
    b (numpy.ndarray): Right-hand side vector.

    Returns:
    numpy.ndarray: The solution vector x.
    """
    # Form the augmented matrix
    augmented_matrix = np.hstack((A, b.reshape(-1, 1)))

    # Number of rows
    n = len(b)

    # Gaussian elimination
    for i in range(n):
        # Make the diagonal element 1
        a = augmented_matrix[i, i]
        augmented_matrix[i] = augmented_matrix[i] / a

        # Make the below rows' corresponding column elements 0
        for j in range(i+1, n):
            b = augmented_matrix[j, i]
            augmented_matrix[j] = augmented_matrix[j] - b * augmented_matrix[i]

    # Back substitution
    x = np.zeros(n)
    for i in range(n-1, -1, -1):
        x[i] = augmented_matrix[i, n] - np.dot(augmented_matrix[i, i+1:n], x[i+1:n])

    return x, augmented_matrix

# Define the system
A = np.array([[2, 3], [5, 4]])
b = np.array([8, 20])

# Perform Gaussian elimination
solution, transformation_steps = gaussian_elimination(A, b)

# Plotting the intermediate steps
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
axs[0].matshow(A, cmap='viridis')
axs[0].set_title('Original Matrix')
axs[1].matshow(transformation_steps[:, :-1], cmap='viridis')
axs[1].set_title('After Gaussian Elimination')
axs[2].matshow(np.column_stack((A, b)), cmap='viridis')
axs[2].set_title('Augmented Matrix')

for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

plt.show()

solution
# Out:
# array([4., 0.])
